# %%
import pandas as pd
import nltk
from nltk.corpus import stopwords
import time
porter = nltk.PorterStemmer()
stopwords = nltk.corpus.stopwords.words('english')

# reading the data file to variable osdr
try:
    f = open('osdr_short.json')
    osdr = pd.read_json(f)
except Exception as e:
    print("Sorry, there was an error. Data file osdr_short.json is needed")
    print(e)
    
# variable for full text content
osdr_full_text = ""

# fetching the text content from osdr to osdr_full_text and testing for unwanted values
for ind in osdr.index:
    test_name = isinstance(osdr['name'][ind], str)
    test_descr = isinstance(osdr['description'][ind], str)
    if test_name and test_descr:
        osdr_full_text = osdr_full_text + osdr['name'][ind] + " " + osdr['description'][ind] + " "
    else:
        print("Bad values in data file index", ind)

print("\nFull text length", len(osdr_full_text))

# tokenizing full text, not everything is used
tokens = nltk.wordpunct_tokenize(osdr_full_text)
tokens_text = nltk.Text(tokens)
words = [w.lower for w in tokens_text]
vocabulary = sorted(set([word.lower() for word in tokens if word.isalpha()]))

# something unfinished
#fdist = nltk.FreqDist(osdr_full_text)
#print("Freqdist")
#print(fdist)

# creating trimmed vocabulary using stopwords
trimmed_vocabulary = []

for word in vocabulary:
    #print(word)
    if word not in stopwords:
        trimmed_vocabulary.append(word)

# stemming and tagging the trimmed vocabulary
stemmed_vocabulary = [porter.stem(t) for t in trimmed_vocabulary]
tagged_vocabulary = nltk.pos_tag(trimmed_vocabulary)

# printing vocabularies and some data

print("\nVocabulary")
print(vocabulary)

print("\nTrimmed vocabulary")
print(trimmed_vocabulary)

print("\nStemmed vocabulary")
print(stemmed_vocabulary)

print("\nTagged vocabulary")
print(tagged_vocabulary)

print(f"\nLength of the trimmed vocabulary: {len(trimmed_vocabulary)}")
print(f"Length of the original vocabulary {len(vocabulary)}")

print(f"Content fraction of trimmed / original vocabulary: {len(trimmed_vocabulary)/len(vocabulary)}")

# function for saving vocabulary files
def save_file(name, content):
    try:  
        f = open(f"{name}_{time.time()}.txt", "x")
        f.write("[")
        for index, word in enumerate(content):
            #len(content)
            if index < len(content)-1:
                f.write(f"'{word}', ")
            else:
                f.write(f"'{word}'")
        f.write("]")
        f.close()
        print(f"saved {name}_{time.time()}.txt")
    except Exception as e:
        print("Sorry, there was an error")
        print(e)

# prompting for saving vocabulary to a text file
print(f"\nSave vocabulary to text file? (y - Yes, anything else - No):")
inputcommand = input("")
if inputcommand == "y":
    save_file("vocabulary", vocabulary)

# prompting for saving trimmed vocabulary to a text file
print(f"\nSave trimmed vocabulary to text file? (y - Yes, anything else - No):")
inputcommand = input("")
if inputcommand == "y":
    save_file("trimmed_vocabulary", trimmed_vocabulary)

# prompting for saving stemmed vocabulary to a text file
print(f"\nSave stemmed vocabulary to text file? (y - Yes, anything else - No):")
inputcommand = input("")
if inputcommand == "y":
    save_file("stemmed_vocabulary", stemmed_vocabulary)

# prompting for saving tagged vocabulary to a text file
print(f"\nSave tagged vocabulary to text file? (y - Yes, anything else - No):")
inputcommand = input("")
if inputcommand == "y":
    save_file("tagged_vocabulary", tagged_vocabulary)

print("End of program")
# Out:
# Bad values in data file index 49
# Bad values in data file index 53
#
# Full text length 130645
#
# Vocabulary
# ['a', 'aaeu', 'aau', 'ability', 'able', 'aboard', 'about', 'above', 'absorb', 'absorbed', 'absorbent', 'absorbing', 'absorbs', 'absorptiometry', 'absorption', 'abundant', 'accelerates', 'acceleration', 'accelerator', 'accelerometer', 'access', 'accessed', 'accessible', 'accessories', 'accessory', 'accidental', 'accommodate', 'accommodates', 'accommodations', 'accomodate', 'accomplish', 'accomplished', 'accumulator', 'accurate', 'achieve', 'acid', 'acids', 'acoustic', 'acoustics', 'acquire', 'acquired', 'acquires', 'acquisition', 'across', 'acrylic', 'act', 'action', 'activate', 'activated', 'activates', 'activation', 'active', 'actively', 'activities', 'activity', 'actuate', 'actuated', 'actuates', 'actuation', 'actuations', 'actuator', 'ad', 'adaptations', 'adapted', 'adapter', 'adapts', 'add', 'added', 'adding', 'addition', 'additional', 'additionally', 'additions', 'addressing', 'adequate', 'adf', 'adherence', 'adherent', 'adjacent', 'adjust', 'adjustable', 'adjusted', 'adjustments', 'adult', 'advanced', 'aem', 'aerospace', 'af', 'affected', 'affects', 'affixed', 'afs', 'aft', 'afte', 'after', 'ag', 'again', 'against', 'agar', 'agency', 'agent', 'agreement', 'aid', 'air', 'airflow', 'airline', 'airlock', 'airtight', 'akc', 'algae', 'align', 'alkaline', 'all', 'allow', 'allowed', 'allowing', 'allows', 'alloy', 'almost', 'alone', 'along', 'also', 'altered', 'altitude', 'aluminum', 'amalgam', 'ambient', 'ambulatory', 'ameliorate', 'ames', 'amniotic', 'amoeba', 'amount', 'amounts', 'amp', 'amphibia', 'amphibians', 'amplifier', 'amplitude', 'an', 'analog', 'analysis', 'analyzed', 'and', 'anesthetized', 'anethesia', 'angled', 'angles', 'animal', 'animals', 'ankle', 'anodized', 'another', 'anoxia', 'antenna', 'antennas', 'anticipated', 'any', 'apart', 'apd', 'apertures', 'aph', 'apollo', 'apparatus', 'appear', 'application', 'applications', 'applied', 'applying', 'appropriate', 'approximately', 'aquatic', 'ar', 'arabidopsis', 'arbacia', 'architecture', 'archive', 'are', 'area', 'areas', 'arf', 'arm', 'armports', 'arms', 'around', 'arranged', 'arrangements', 'array', 'arrest', 'arrive', 'ars', 'artificial', 'as', 'ascent', 'ashed', 'assemble', 'assembled', 'assemblies', 'assembly', 'assisted', 'associated', 'assure', 'astronauts', 'at', 'atcus', 'atmosphere', 'atmospheric', 'atr', 'attached', 'attachment', 'attainable', 'au', 'audio', 'auditory', 'autoclavable', 'autogenic', 'automated', 'automatic', 'automatically', 'autonomous', 'autonomously', 'auxiliary', 'available', 'avian', 'avionics', 'awa', 'axes', 'axial', 'axillary', 'axis', 'b', 'back', 'background', 'backlight', 'backscattering', 'backup', 'bacteria', 'bacterial', 'baffled', 'baffles', 'bag', 'bagging', 'bags', 'bakeable', 'baksan', 'balance', 'bam', 'bank', 'bar', 'barrel', 'barrier', 'bars', 'basal', 'base', 'based', 'basic', 'batch', 'bathes', 'batteries', 'battery', 'bay', 'bd', 'be', 'beam', 'beamline', 'beams', 'beats', 'because', 'become', 'been', 'beeswax', 'beetle', 'beetles', 'before', 'begins', 'behavior', 'behavioral', 'behind', 'being', 'below', 'belt', 'bending', 'beneath', 'between', 'billion', 'biochamber', 'biochambers', 'biocompatible', 'biocore', 'bioculture', 'biological', 'biology', 'biomarker', 'biomass', 'biomphalaria', 'bion', 'biopack', 'bioprocessing', 'bioproduct', 'biorack', 'bioreactor', 'bios', 'biosampling', 'biosatellite', 'biosatellites', 'bioscience', 'bioserve', 'biotechnology', 'biotelemetry', 'bit', 'bka', 'bladders', 'blanket', 'blood', 'blue', 'bmd', 'bnl', 'bno', 'board', 'boards', 'bochum', 'body', 'bolted', 'bonded', 'bonding', 'bone', 'boomerang', 'booster', 'botany', 'botex', 'both', 'bottles', 'bottom', 'boundary', 'bounded', 'box', 'boxes', 'bps', 'brackets', 'brain', 'bread', 'breakage', 'breathable', 'breaths', 'bremen', 'bric', 'bring', 'broad', 'brookhaven', 'brush', 'bsl', 'bts', 'bud', 'buds', 'builds', 'built', 'bulgarian', 'bulk', 'burned', 'burning', 'business', 'but', 'button', 'by', 'bypass', 'byte', 'c', 'ca', ' ...
#
# Trimmed vocabulary
# ['aaeu', 'aau', 'ability', 'able', 'aboard', 'absorb', 'absorbed', 'absorbent', 'absorbing', 'absorbs', 'absorptiometry', 'absorption', 'abundant', 'accelerates', 'acceleration', 'accelerator', 'accelerometer', 'access', 'accessed', 'accessible', 'accessories', 'accessory', 'accidental', 'accommodate', 'accommodates', 'accommodations', 'accomodate', 'accomplish', 'accomplished', 'accumulator', 'accurate', 'achieve', 'acid', 'acids', 'acoustic', 'acoustics', 'acquire', 'acquired', 'acquires', 'acquisition', 'across', 'acrylic', 'act', 'action', 'activate', 'activated', 'activates', 'activation', 'active', 'actively', 'activities', 'activity', 'actuate', 'actuated', 'actuates', 'actuation', 'actuations', 'actuator', 'ad', 'adaptations', 'adapted', 'adapter', 'adapts', 'add', 'added', 'adding', 'addition', 'additional', 'additionally', 'additions', 'addressing', 'adequate', 'adf', 'adherence', 'adherent', 'adjacent', 'adjust', 'adjustable', 'adjusted', 'adjustments', 'adult', 'advanced', 'aem', 'aerospace', 'af', 'affected', 'affects', 'affixed', 'afs', 'aft', 'afte', 'ag', 'agar', 'agency', 'agent', 'agreement', 'aid', 'air', 'airflow', 'airline', 'airlock', 'airtight', 'akc', 'algae', 'align', 'alkaline', 'allow', 'allowed', 'allowing', 'allows', 'alloy', 'almost', 'alone', 'along', 'also', 'altered', 'altitude', 'aluminum', 'amalgam', 'ambient', 'ambulatory', 'ameliorate', 'ames', 'amniotic', 'amoeba', 'amount', 'amounts', 'amp', 'amphibia', 'amphibians', 'amplifier', 'amplitude', 'analog', 'analysis', 'analyzed', 'anesthetized', 'anethesia', 'angled', 'angles', 'animal', 'animals', 'ankle', 'anodized', 'another', 'anoxia', 'antenna', 'antennas', 'anticipated', 'apart', 'apd', 'apertures', 'aph', 'apollo', 'apparatus', 'appear', 'application', 'applications', 'applied', 'applying', 'appropriate', 'approximately', 'aquatic', 'ar', 'arabidopsis', 'arbacia', 'architecture', 'archive', 'area', 'areas', 'arf', 'arm', 'armports', 'arms', 'around', 'arranged', 'arrangements', 'array', 'arrest', 'arrive', 'ars', 'artificial', 'ascent', 'ashed', 'assemble', 'assembled', 'assemblies', 'assembly', 'assisted', 'associated', 'assure', 'astronauts', 'atcus', 'atmosphere', 'atmospheric', 'atr', 'attached', 'attachment', 'attainable', 'au', 'audio', 'auditory', 'autoclavable', 'autogenic', 'automated', 'automatic', 'automatically', 'autonomous', 'autonomously', 'auxiliary', 'available', 'avian', 'avionics', 'awa', 'axes', 'axial', 'axillary', 'axis', 'b', 'back', 'background', 'backlight', 'backscattering', 'backup', 'bacteria', 'bacterial', 'baffled', 'baffles', 'bag', 'bagging', 'bags', 'bakeable', 'baksan', 'balance', 'bam', 'bank', 'bar', 'barrel', 'barrier', 'bars', 'basal', 'base', 'based', 'basic', 'batch', 'bathes', 'batteries', 'battery', 'bay', 'bd', 'beam', 'beamline', 'beams', 'beats', 'become', 'beeswax', 'beetle', 'beetles', 'begins', 'behavior', 'behavioral', 'behind', 'belt', 'bending', 'beneath', 'billion', 'biochamber', 'biochambers', 'biocompatible', 'biocore', 'bioculture', 'biological', 'biology', 'biomarker', 'biomass', 'biomphalaria', 'bion', 'biopack', 'bioprocessing', 'bioproduct', 'biorack', 'bioreactor', 'bios', 'biosampling', 'biosatellite', 'biosatellites', 'bioscience', 'bioserve', 'biotechnology', 'biotelemetry', 'bit', 'bka', 'bladders', 'blanket', 'blood', 'blue', 'bmd', 'bnl', 'bno', 'board', 'boards', 'bochum', 'body', 'bolted', 'bonded', 'bonding', 'bone', 'boomerang', 'booster', 'botany', 'botex', 'bottles', 'bottom', 'boundary', 'bounded', 'box', 'boxes', 'bps', 'brackets', 'brain', 'bread', 'breakage', 'breathable', 'breaths', 'bremen', 'bric', 'bring', 'broad', 'brookhaven', 'brush', 'bsl', 'bts', 'bud', 'buds', 'builds', 'built', 'bulgarian', 'bulk', 'burned', 'burning', 'business', 'button', 'bypass', 'byte', 'c', 'ca', 'cabin', 'cabinet', 'cable', 'cables', 'cabs', 'cadmium', 'caesium', 'cage', 'cages', 'calcium', 'calculate', 'calculates', 'calibrated', 'calibrating', 'calibration', 'called', 'callu ...
#
# Stemmed vocabulary
# ['aaeu', 'aau', 'abil', 'abl', 'aboard', 'absorb', 'absorb', 'absorb', 'absorb', 'absorb', 'absorptiometri', 'absorpt', 'abund', 'acceler', 'acceler', 'acceler', 'acceleromet', 'access', 'access', 'access', 'accessori', 'accessori', 'accident', 'accommod', 'accommod', 'accommod', 'accomod', 'accomplish', 'accomplish', 'accumul', 'accur', 'achiev', 'acid', 'acid', 'acoust', 'acoust', 'acquir', 'acquir', 'acquir', 'acquisit', 'across', 'acryl', 'act', 'action', 'activ', 'activ', 'activ', 'activ', 'activ', 'activ', 'activ', 'activ', 'actuat', 'actuat', 'actuat', 'actuat', 'actuat', 'actuat', 'ad', 'adapt', 'adapt', 'adapt', 'adapt', 'add', 'ad', 'ad', 'addit', 'addit', 'addit', 'addit', 'address', 'adequ', 'adf', 'adher', 'adher', 'adjac', 'adjust', 'adjust', 'adjust', 'adjust', 'adult', 'advanc', 'aem', 'aerospac', 'af', 'affect', 'affect', 'affix', 'af', 'aft', 'aft', 'ag', 'agar', 'agenc', 'agent', 'agreement', 'aid', 'air', 'airflow', 'airlin', 'airlock', 'airtight', 'akc', 'alga', 'align', 'alkalin', 'allow', 'allow', 'allow', 'allow', 'alloy', 'almost', 'alon', 'along', 'also', 'alter', 'altitud', 'aluminum', 'amalgam', 'ambient', 'ambulatori', 'amelior', 'ame', 'amniot', 'amoeba', 'amount', 'amount', 'amp', 'amphibia', 'amphibian', 'amplifi', 'amplitud', 'analog', 'analysi', 'analyz', 'anesthet', 'anethesia', 'angl', 'angl', 'anim', 'anim', 'ankl', 'anod', 'anoth', 'anoxia', 'antenna', 'antenna', 'anticip', 'apart', 'apd', 'apertur', 'aph', 'apollo', 'apparatu', 'appear', 'applic', 'applic', 'appli', 'appli', 'appropri', 'approxim', 'aquat', 'ar', 'arabidopsi', 'arbacia', 'architectur', 'archiv', 'area', 'area', 'arf', 'arm', 'armport', 'arm', 'around', 'arrang', 'arrang', 'array', 'arrest', 'arriv', 'ar', 'artifici', 'ascent', 'ash', 'assembl', 'assembl', 'assembl', 'assembl', 'assist', 'associ', 'assur', 'astronaut', 'atcu', 'atmospher', 'atmospher', 'atr', 'attach', 'attach', 'attain', 'au', 'audio', 'auditori', 'autoclav', 'autogen', 'autom', 'automat', 'automat', 'autonom', 'autonom', 'auxiliari', 'avail', 'avian', 'avion', 'awa', 'axe', 'axial', 'axillari', 'axi', 'b', 'back', 'background', 'backlight', 'backscatt', 'backup', 'bacteria', 'bacteri', 'baffl', 'baffl', 'bag', 'bag', 'bag', 'bakeabl', 'baksan', 'balanc', 'bam', 'bank', 'bar', 'barrel', 'barrier', 'bar', 'basal', 'base', 'base', 'basic', 'batch', 'bath', 'batteri', 'batteri', 'bay', 'bd', 'beam', 'beamlin', 'beam', 'beat', 'becom', 'beeswax', 'beetl', 'beetl', 'begin', 'behavior', 'behavior', 'behind', 'belt', 'bend', 'beneath', 'billion', 'biochamb', 'biochamb', 'biocompat', 'biocor', 'biocultur', 'biolog', 'biolog', 'biomark', 'biomass', 'biomphalaria', 'bion', 'biopack', 'bioprocess', 'bioproduct', 'biorack', 'bioreactor', 'bio', 'biosampl', 'biosatellit', 'biosatellit', 'bioscienc', 'bioserv', 'biotechnolog', 'biotelemetri', 'bit', 'bka', 'bladder', 'blanket', 'blood', 'blue', 'bmd', 'bnl', 'bno', 'board', 'board', 'bochum', 'bodi', 'bolt', 'bond', 'bond', 'bone', 'boomerang', 'booster', 'botani', 'botex', 'bottl', 'bottom', 'boundari', 'bound', 'box', 'box', 'bp', 'bracket', 'brain', 'bread', 'breakag', 'breathabl', 'breath', 'bremen', 'bric', 'bring', 'broad', 'brookhaven', 'brush', 'bsl', 'bt', 'bud', 'bud', 'build', 'built', 'bulgarian', 'bulk', 'burn', 'burn', 'busi', 'button', 'bypass', 'byte', 'c', 'ca', 'cabin', 'cabinet', 'cabl', 'cabl', 'cab', 'cadmium', 'caesium', 'cage', 'cage', 'calcium', 'calcul', 'calcul', 'calibr', 'calibr', 'calibr', 'call', 'callu', 'cam', 'camcord', 'camera', 'camera', 'canadian', 'cancel', 'cancer', 'candl', 'canist', 'canist', 'can', 'cap', 'capabl', 'capabl', 'capabl', 'capac', 'cap', 'cap', 'capsicum', 'capsul', 'captur', 'carbon', 'card', 'cardiovascular', 'card', 'cargo', 'carousel', 'carousel', 'carpet', 'carri', 'carri', 'carrot', 'carri', 'carri', 'case', 'case', 'cassett', 'cassett', 'cathod', 'caus', 'caviti', 'caviti', 'cc', 'cck', 'ccm', 'cd', 'ceba', 'ceil', 'cell', 'cell', 'cellular', 'celsiu', 'cente ...
#
# Tagged vocabulary
# [('aaeu', 'JJ'), ('aau', 'NN'), ('ability', 'NN'), ('able', 'JJ'), ('aboard', 'NN'), ('absorb', 'VB'), ('absorbed', 'JJ'), ('absorbent', 'JJ'), ('absorbing', 'VBG'), ('absorbs', 'JJ'), ('absorptiometry', 'NN'), ('absorption', 'NN'), ('abundant', 'JJ'), ('accelerates', 'VBZ'), ('acceleration', 'NN'), ('accelerator', 'NN'), ('accelerometer', 'NN'), ('access', 'NN'), ('accessed', 'VBD'), ('accessible', 'JJ'), ('accessories', 'NNS'), ('accessory', 'VBP'), ('accidental', 'JJ'), ('accommodate', 'NN'), ('accommodates', 'NNS'), ('accommodations', 'NNS'), ('accomodate', 'VBP'), ('accomplish', 'JJ'), ('accomplished', 'VBN'), ('accumulator', 'NN'), ('accurate', 'NN'), ('achieve', 'VBP'), ('acid', 'NN'), ('acids', 'NNS'), ('acoustic', 'JJ'), ('acoustics', 'NNS'), ('acquire', 'VB'), ('acquired', 'VBN'), ('acquires', 'NNS'), ('acquisition', 'NN'), ('across', 'IN'), ('acrylic', 'JJ'), ('act', 'NN'), ('action', 'NN'), ('activate', 'RB'), ('activated', 'VBD'), ('activates', 'NNS'), ('activation', 'VBP'), ('active', 'JJ'), ('actively', 'RB'), ('activities', 'NNS'), ('activity', 'NN'), ('actuate', 'RB'), ('actuated', 'VBN'), ('actuates', 'NNS'), ('actuation', 'VBP'), ('actuations', 'NNS'), ('actuator', 'VBP'), ('ad', 'NN'), ('adaptations', 'NNS'), ('adapted', 'VBD'), ('adapter', 'NN'), ('adapts', 'NNS'), ('add', 'VBP'), ('added', 'VBD'), ('adding', 'VBG'), ('addition', 'NN'), ('additional', 'JJ'), ('additionally', 'RB'), ('additions', 'NNS'), ('addressing', 'VBG'), ('adequate', 'JJ'), ('adf', 'NNS'), ('adherence', 'NN'), ('adherent', 'JJ'), ('adjacent', 'JJ'), ('adjust', 'NN'), ('adjustable', 'JJ'), ('adjusted', 'JJ'), ('adjustments', 'NNS'), ('adult', 'NN'), ('advanced', 'VBD'), ('aem', 'JJ'), ('aerospace', 'NN'), ('af', 'NN'), ('affected', 'VBD'), ('affects', 'NNS'), ('affixed', 'JJ'), ('afs', 'NN'), ('aft', 'NN'), ('afte', 'NN'), ('ag', 'NN'), ('agar', 'NN'), ('agency', 'NN'), ('agent', 'NN'), ('agreement', 'NN'), ('aid', 'NN'), ('air', 'NN'), ('airflow', 'JJ'), ('airline', 'NN'), ('airlock', 'NN'), ('airtight', 'VBD'), ('akc', 'JJ'), ('algae', 'JJ'), ('align', 'NN'), ('alkaline', 'NN'), ('allow', 'NN'), ('allowed', 'VBD'), ('allowing', 'VBG'), ('allows', 'NNS'), ('alloy', 'VBP'), ('almost', 'RB'), ('alone', 'RB'), ('along', 'RB'), ('also', 'RB'), ('altered', 'VBN'), ('altitude', 'NN'), ('aluminum', 'NN'), ('amalgam', 'NN'), ('ambient', 'JJ'), ('ambulatory', 'NN'), ('ameliorate', 'NN'), ('ames', 'NNS'), ('amniotic', 'JJ'), ('amoeba', 'NN'), ('amount', 'NN'), ('amounts', 'NNS'), ('amp', 'VBP'), ('amphibia', 'JJ'), ('amphibians', 'NNS'), ('amplifier', 'VBP'), ('amplitude', 'JJ'), ('analog', 'NN'), ('analysis', 'NN'), ('analyzed', 'VBD'), ('anesthetized', 'JJ'), ('anethesia', 'NN'), ('angled', 'VBD'), ('angles', 'NNS'), ('animal', 'JJ'), ('animals', 'NNS'), ('ankle', 'VBP'), ('anodized', 'VBN'), ('another', 'DT'), ('anoxia', 'NN'), ('antenna', 'NN'), ('antennas', 'NNS'), ('anticipated', 'VBN'), ('apart', 'RB'), ('apd', 'JJ'), ('apertures', 'NNS'), ('aph', 'VBP'), ('apollo', 'JJ'), ('apparatus', 'NN'), ('appear', 'VBP'), ('application', 'NN'), ('applications', 'NNS'), ('applied', 'VBD'), ('applying', 'VBG'), ('appropriate', 'JJ'), ('approximately', 'RB'), ('aquatic', 'JJ'), ('ar', 'NN'), ('arabidopsis', 'NN'), ('arbacia', 'JJ'), ('architecture', 'NN'), ('archive', 'JJ'), ('area', 'NN'), ('areas', 'NNS'), ('arf', 'VBP'), ('arm', 'NN'), ('armports', 'NNS'), ('arms', 'NNS'), ('around', 'IN'), ('arranged', 'JJ'), ('arrangements', 'NNS'), ('array', 'JJ'), ('arrest', 'RB'), ('arrive', 'JJ'), ('ars', 'NNS'), ('artificial', 'JJ'), ('ascent', 'NN'), ('ashed', 'VBD'), ('assemble', 'JJ'), ('assembled', 'JJ'), ('assemblies', 'NNS'), ('assembly', 'RB'), ('assisted', 'VBD'), ('associated', 'JJ'), ('assure', 'NN'), ('astronauts', 'VBZ'), ('atcus', 'RB'), ('atmosphere', 'JJ'), ('atmospheric', 'JJ'), ('atr', 'NN'), ('attached', 'VBD'), ('attachment', 'JJ'), ('attainable', 'JJ'), ('au', 'NN'), ('audio', 'JJ'), ('auditory', 'NN'), ('autoclavable', 'JJ'), ('autogeni ...
#
# Length of the trimmed vocabulary: 3135
# Length of the original vocabulary 3236
# Content fraction of trimmed / original vocabulary: 0.9687886279357231
#
# Save vocabulary to text file? (y - Yes, anything else - No):
# Save trimmed vocabulary to text file? (y - Yes, anything else - No):
# Save stemmed vocabulary to text file? (y - Yes, anything else - No):
# Save tagged vocabulary to text file? (y - Yes, anything else - No):
# End of program
